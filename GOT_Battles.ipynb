# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets/battles.csv')

# %%
df.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
df.isna().sum()
# Out:
# name                   0
# year                   0
# battle_number          0
# attacker_king          2
# defender_king          3
# attacker_1             0
# attacker_2            28
# attacker_3            35
# attacker_4            36
# defender_1             1
# defender_2            36
# defender_3            38
# defender_4            38
# attacker_outcome       1
# battle_type            1
# major_death            1
# major_capture          1
# attacker_size         14
# defender_size         19
# attacker_commander     1
# defender_commander    10
# summer                 1
# location               1
# region                 0
# note                  33
# dtype: int64

# %%
print('Attacker king counts')
print(df['attacker_king'].value_counts())
print('\nDefender king counts')
print(df['defender_king'].value_counts())
# Out:
# Attacker king counts
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# Name: attacker_king, dtype: int64
#
# Defender king counts
# Robb Stark                  14
# Joffrey/Tommen Baratheon    13
# Balon/Euron Greyjoy          4
# Stannis Baratheon            2
# Renly Baratheon              1
# Mance Rayder                 1
# Name: defender_king, dtype: int64

# %% [markdown]
# ### Attacker King vs. Attacker Army

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='attacker_king', y='attacker_size', data=df)
# Out:
# <AxesSubplot:xlabel='attacker_king', ylabel='attacker_size'>

# %% [markdown]
# ### Defender King vs. Defender Army

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='defender_king', y='defender_size', data=df)
# Out:
# <AxesSubplot:xlabel='defender_king', ylabel='defender_size'>

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='attacker_king', hue='battle_type', data=df)
plt.show()

# %% [markdown]
# ### Characters

# %%
df2 = pd.read_csv('datasets/character-deaths.csv')
df2.head()
# Out:
#                       Name      Allegiances  Death Year  Book of Death  \
# 0           Addam Marbrand        Lannister         NaN            NaN
# 1  Aegon Frey (Jinglebell)             None       299.0            3.0
# 2          Aegon Targaryen  House Targaryen         NaN            NaN
# 3            Adrack Humble    House Greyjoy       300.0            5.0
# 4           Aemon Costayne        Lannister         NaN            NaN
#
#    Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0            NaN                56.0       1         1    1    1    1    1
# 1           51.0                49.0       1         1    0    0    1    0
# 2            NaN                 5.0       1         1    0    0    0    0
# 3           20.0                20.0       1         1    0    0    0    0
# 4            NaN                 NaN       1         1    0    0    1    0
#
#    DwD
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0

# %%
plt.figure(figsize=(10,5))
sns.countplot(df2['Gender'], hue=df2['Death Year'])
# Out:
# C:\Users\ankan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(30,50))
sns.countplot(y=df2['Allegiances'], hue=df2['Gender'])
sns.set(font_scale = 3)
plt.xlabel('Allegiances',fontsize=24)
plt.ylabel('Count',fontsize=24)
# Out:
# Text(0, 0.5, 'Count')
